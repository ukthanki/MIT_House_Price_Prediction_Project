# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("drinks_dataset.csv")
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan              0                0              0
# 1             1      Albania             89              132             54
# 2             2      Algeria             25                0             14
# 3             3      Andorra            245              138            312
# 4             4       Angola            217               57             45
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            333              100              3
# 189         189      Vietnam            111                2              1
# 190         190        Yemen              6                0              0
# 191         191       Zambia             32               19              4
# 192         192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
asia_data = df[df["continent"] == "Asia"]
asia_data
# Out:
#      Unnamed: 0               country  beer_servings  spirit_servings  \
# 0             0           Afghanistan              0                0
# 12           12               Bahrain             42               63
# 13           13            Bangladesh              0                0
# 19           19                Bhutan             23                0
# 24           24                Brunei             31                2
# 30           30              Cambodia             57               65
# 36           36                 China             79              192
# 46           46           North Korea              0                0
# 77           77                 India              9              114
# 78           78             Indonesia              5                1
# 79           79                  Iran              0                0
# 80           80                  Iraq              9                3
# ...

# %%
asia_beer = asia_data["beer_servings"]
asia_spirits = asia_data["spirit_servings"]
asia_wine = asia_data["wine_servings"]

# %%
asia_beer.corr(asia_spirits, method="pearson")
# Out:
# 0.6944264281424213

# %%
asia_beer.corr(asia_wine)
# Out:
# 0.4374881921115878

# %%
asia_data.corr(method="pearson").drop("Unnamed: 0").drop("Unnamed: 0", axis=1)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.694426       0.437488
# spirit_servings                    0.694426         1.000000       0.225150
# wine_servings                      0.437488         0.225150       1.000000
# total_litres_of_pure_alcohol       0.899253         0.772893       0.533320
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.899253
# spirit_servings                                   0.772893
# wine_servings                                     0.533320
# total_litres_of_pure_alcohol                      1.000000

# %%
NA_data = df[df["continent"] == "North America"]
NA_data
# Out:
#      Unnamed: 0                       country  beer_servings  spirit_servings  \
# 5             5             Antigua & Barbuda            102              128
# 11           11                       Bahamas            122              176
# 14           14                      Barbados            143              173
# 17           17                        Belize            263              114
# 32           32                        Canada            240              122
# 41           41                    Costa Rica            149               87
# 43           43                          Cuba             93              137
# 50           50                      Dominica             52              286
# 51           51            Dominican Republic            193              147
# 54           54                   El Salvador             52               69
# 68           68                       Grenada            199              438
# ...

# %%
NA_beer = NA_data["beer_servings"]
NA_spirits = NA_data["spirit_servings"]
NA_wine = NA_data["wine_servings"]

# %%
NA_beer.corr(NA_spirits, method="pearson")
# Out:
# -0.07341089867033729

# %%
NA_beer.corr(NA_wine)
# Out:
# 0.409037697191913

# %%
NA_data.corr(method="pearson").drop("Unnamed: 0").drop("Unnamed: 0", axis=1)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000        -0.073411       0.409038
# spirit_servings                   -0.073411         1.000000       0.219815
# wine_servings                      0.409038         0.219815       1.000000
# total_litres_of_pure_alcohol       0.612514         0.720400       0.608532
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.612514
# spirit_servings                                   0.720400
# wine_servings                                     0.608532
# total_litres_of_pure_alcohol                      1.000000
